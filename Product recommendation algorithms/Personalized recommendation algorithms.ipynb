# %% [markdown]
# <center><img src='https://sedigitalylanzate.es/wp-content/uploads/2019/03/logoeoiok-e1552040050697.png' width="500"></center>

# %% [markdown]
# <center><img src='https://m.media-amazon.com/images/S/aplus-media-library-service-media/0abb9e09-3550-47f8-ae9a-92385718a879.__CR0,0,2500,750_PT0_SX600_V1___.png' width="500"></center>

# %% [markdown]
# # Contexto del ejercicio
# ## Tercera prueba en RecomiendaME (RME)
#
# Si estás aquí eso significa que no has abanadonado por el camino. Ya solamente queda una prueba más.
#
# Volvemos a nuestra fuente de datos original (las puntuaciones de Twitter), en este caso te la vamos a pasar en crudo. Eso si hemos filtrado 1000 usuarios para que puedas ejecutarlo con la RAM que ofrece colab.
#
# Ahora vas a tener la información de cada valoración de un usuario a una película.
#
# Con esa base vas a tener que generar la recomendación para cada usuario con el paquete `surprise`.
#
# Lo importante aquí es que presentes el modelo con el mejor ajuste posible, que detalles esas pruebas y que nos enseñes algún ejemplo.
#
# ## Análisis a desarrollar
#
# - Partiendo del fichero **ratings_filtrado.csv**.
#
# - Cárgalo con la funcion `Reader y Dataset del paquete Surprise`
#
# - Haz un benchmark de los siguientes algoritmos, que ya hemos comprobado que no dan problemas.
#
# `SVD(), SlopeOne(), NormalPredictor(), KNNBaseline(), KNNBasic(), KNNWithMeans(), KNNWithZScore(), BaselineOnly(), CoClustering()`
#
# - Genera las recomendaciones para luego enseñar alguna.
#
# - Justifica tu elección en el informe y presentanos algún ejemplo.
#
# **Nota:** Seguro que si sacas alguna estadística de cuáles son los contenidos más recomendados o algo que se te ocurra será bien valorado por los directivos de RecomiendaME (RME).
#
# **Nota2:** Si quieres recuperar el título de la película lo tienes en el fichero medias.csv del ejercicio 1.
#
# ### Suerte!

# %%
# !pip install plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install plotly==5.13.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install chart_studio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 KB 2.6 MB/s eta 0:00:00
# ...

# %%
# !pip install surprise
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 KB 12.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp39-cp39-linux_x86_64.whl size=3193665 sha256=f4b63e2ac82c50d65ae6bff4c34e0238639b62dfc368af983032f9a3c0e497e2
#   Stored in directory: /root/.cache/pip/wheels/c6/3a/46/9b17b3512bdf283c6cb84f59929cdd5199d4e754d596d22784
# Successfully built scikit-surprise
# ...

# %%
import plotly.tools as tls
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import chart_studio.plotly as py
import chart_studio.tools as tls

import pandas as pd
import numpy as np

from surprise import Reader, Dataset, SVD
from surprise import Dataset, Reader
from surprise.model_selection import cross_validate, train_test_split
from surprise import SVD, SlopeOne, NormalPredictor, KNNBaseline, KNNBasic, KNNWithMeans, KNNWithZScore, BaselineOnly, CoClustering
from surprise.model_selection import train_test_split
from itertools import groupby

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_movies = pd.read_csv('/content/drive/MyDrive/MASTER EOI/16. MODULO 16. Sistemas recomendadores de productos/Ejercicios_Entregas/material_apoyo/movies_etiquetado.csv')
df_rating_filtrados = pd.read_csv('/content/drive/MyDrive/MASTER EOI/16. MODULO 16. Sistemas recomendadores de productos/Ejercicios_Entregas/material_apoyo/ratings_filtratos.csv')

# %% [markdown]
# Primero, cargamos los datos del archivo "ratings_filtrado.csv" en un objeto Dataset de Surprise, utilizando el objeto Reader para definir el formato del archivo. El archivo contiene cuatro columnas: user_id, imdb_id, rating y time.

# %%
# Carga de datos y preparación de datos para Surprise
reader = Reader(rating_scale=(1, 10))
df_Surprise = Dataset.load_from_df(df_rating_filtrados[['user_id', 'imdb_id', 'rating']], reader)

# División en conjuntos de entrenamiento y prueba
trainset, testset = train_test_split(df_Surprise, test_size=0.2, random_state=42)

# Definición de algoritmos
algorithms = [SVD(), SlopeOne(), NormalPredictor(), KNNBaseline(), KNNBasic(), KNNWithMeans(), KNNWithZScore(), BaselineOnly(), CoClustering()]

# Evaluación de los algoritmos mediante validación cruzada
results = {}
for algo in algorithms:
    res = cross_validate(algo, df_Surprise, measures=['RMSE', 'MAE'], cv=5, verbose=False)
    results[algo.__class__.__name__] = [np.mean(res['test_rmse']), np.mean(res['test_mae']), np.mean(res['fit_time']), np.mean(res['test_time'])]

# Crear un DataFrame con los resultados del benchmark
resultsBenchmark_df = pd.DataFrame.from_dict(results, orient='index', columns=['RMSE', 'MAE', 'Fit Time', 'Test Time'])

# Mostrar el DataFrame
resultsBenchmark_df = resultsBenchmark_df.sort_values(by='RMSE')
# Out:
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# ...

# %%
resultsBenchmark_df = resultsBenchmark_df.sort_values(by='RMSE')
resultsBenchmark_df
# Out:
#                      RMSE       MAE  Fit Time  Test Time
# BaselineOnly     1.518949  1.129375  0.159388   0.114273
# SVD              1.529732  1.132446  1.087639   0.134463
# KNNBaseline      1.574430  1.163271  0.207940   0.578067
# KNNWithMeans     1.627119  1.201913  0.097276   0.760321
# KNNWithZScore    1.629600  1.191101  0.193466   0.726743
# CoClustering     1.649781  1.220194  2.118273   0.111457
# SlopeOne         1.662809  1.240284  2.793182   1.128861
# KNNBasic         1.738261  1.294964  0.057356   0.475777
# NormalPredictor  2.508181  1.992178  0.096070   0.124474

# %% [markdown]
# ``RMSE y MAE`` son medidas de error en la predicción de los ratings, donde un RMSE más bajo y un MAE más bajo indican una mejor precisión del modelo. Por lo tanto, los modelos con valores más bajos para estas métricas son mejores para este conjunto de datos. Además, Fit Time y Test Time indican el tiempo que tarda el modelo en entrenar y predecir, respectivamente.
#
# Al observar los resultados del benchmark, podemos ver que BaselineOnly y SVD obtienen los valores más bajos de RMSE y MAE, lo que indica que son los modelos más precisos. Además, BaselineOnly tiene un tiempo de ajuste muy bajo, lo que lo hace más eficiente que SVD. KNNBaseline también tiene un RMSE y MAE decentemente bajos y un tiempo de ajuste corto. KNNBasic, KNNWithMeans y KNNWithZScore tienen un RMSE y MAE más alto, lo que indica que son menos precisos que los modelos anteriores. SlopeOne y CoClustering tienen los valores más altos de RMSE y MAE, lo que indica que son los modelos menos precisos. En términos de tiempo de entrenamiento, SlopeOne y CoClustering tardan significativamente más tiempo que los otros modelos. NormalPredictor tiene el tiempo de ajuste más bajo, pero también los valores más altos de RMSE y MAE, lo que indica que es el modelo menos preciso.

# %% [markdown]
# Una vez que hemos realizado el benchmark, podemos seleccionar el algoritmo con el mejor ajuste y utilizarlo para generar recomendaciones para cada usuario. En este caso, seleccionaremos el algoritmo SVD, ya que ha obtenido el mejor resultado en la búsqueda de parámetros.

# %% [markdown]
# Para generar las recomendaciones utilizaremos el algoritmo SVD ya que fue el que obtuvo el menor valor de RMSE y MAE en el benchmark anterior. Además, es un algoritmo muy utilizado en sistemas de recomendación y se espera que tenga buenos resultados en este caso.
#
# Para generar las recomendaciones, primero entrenaremos el modelo SVD con el conjunto de entrenamiento completo y luego utilizaremos el método build_anti_testset() para obtener una lista de posibles recomendaciones para cada usuario. Luego, para cada usuario, utilizaremos el método predict() para predecir la valoración que le daría a cada película en la lista de recomendaciones y seleccionaremos las N películas con mayor valoración para recomendarle al usuario.
#
# A continuación generamos recomendaciones para cada usuario de las 10 películas con mayor valoración:

# %%
# Cargar el archivo CSV en un objeto de dataframe de pandas
recomendacionesAllUsers_df = pd.read_csv('/content/drive/MyDrive/MASTER EOI/16. MODULO 16. Sistemas recomendadores de productos/Ejercicios_Entregas/material_apoyo/ratings_filtratos.csv')

# Definir un objeto de lector de Surprise
reader = Reader(rating_scale=(1, 10))

# Cargar el dataframe en un objeto de datos de Surprise
AllUsers_Surprise_df = Dataset.load_from_df(recomendacionesAllUsers_df[['user_id', 'imdb_id', 'rating']], reader)

# Seleccionar un algoritmo de recomendación de Surprise
algo = SVD()

# Entrenar el modelo de recomendación utilizando el método fit()
trainset = AllUsers_Surprise_df.build_full_trainset()
algo.fit(trainset)

# Generar recomendaciones para cada usuario utilizando el método predict()
trainset = AllUsers_Surprise_df.build_full_trainset()
algo.fit(trainset)

# Generar recomendaciones para todos los usuarios utilizando la función test() de manera vectorizada
testset = trainset.build_anti_testset()
all_user_predictions = algo.test(testset, verbose=False)

# Ordenar las recomendaciones por usuario y valoración estimada descendente
all_user_predictions.sort(key=lambda x: (x.uid, x.est), reverse=True)

# Guardar las mejores recomendaciones en un dataframe
df_recommendations = pd.DataFrame(columns=['user_id', 'imdb_id', 'predicted_rating']).dropna()
for uid, user_predictions in groupby(all_user_predictions, key=lambda x: x.uid):
    top_user_predictions = list(user_predictions)[:10]
    for pred in top_user_predictions:
        df_recommendations = df_recommendations.append({'user_id': uid, 'imdb_id': pred.iid, 'predicted_rating': round(pred.est, 2)}, ignore_index=True)


# Imprimir las mejores recomendaciones para cada usuario
top_n = 10
for uid in trainset.all_users():
    df_user_recommendations = df_recommendations[df_recommendations['user_id'] == uid].head(top_n)
   # print('Las', top_n, 'mejores recomendaciones para el usuario con ID', uid)
   # print(df_user_recommendations)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# <ipython-input-6-a344841faf4e>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_recommendations = df_recommendations.append({'user_id': uid, 'imdb_id': pred.iid, 'predicted_rating': round(pred.est, 2)}, ignore_index=True)
# <ipython-input-6-a344841faf4e>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_recommendations = df_recommendations.append({'user_id': uid, 'imdb_id': pred.iid, 'predicted_rating': round(pred.est, 2)}, ignore_index=True)
# <ipython-input-6-a344841faf4e>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
#RECOMENDACION PARA UN SOLO USUARIO

# Cargar el archivo CSV en un objeto de dataframe de pandas
recomendacionesOneUser_df = pd.read_csv('/content/drive/MyDrive/MASTER EOI/16. MODULO 16. Sistemas recomendadores de productos/Ejercicios_Entregas/material_apoyo/ratings_filtratos.csv')

# Definir un objeto de lector de Surprise
reader = Reader(rating_scale=(1, 10))

# Cargar el dataframe en un objeto de datos de Surprise
OneUser_Surprise_df = Dataset.load_from_df(recomendacionesOneUser_df[['user_id', 'imdb_id', 'rating']], reader)

# Seleccionar un algoritmo de recomendación de Surprise
algo = SVD()

# Entrenar el modelo de recomendación utilizando el método fit()
trainset = OneUser_Surprise_df.build_full_trainset()
algo.fit(trainset)

# Generar recomendaciones para cada usuario utilizando el método predict()
testset = trainset.build_anti_testset()
predictions = algo.test(testset)

# Generar recomendaciones para el usuario con ID:
user_id = 873
user_predictions = []
for uid, iid, true_r, est, _ in predictions:
    if uid == user_id:
        user_predictions.append((iid, est))

# Ordenar las recomendaciones por valoración estimada descendente
user_predictions.sort(key=lambda x: x[1], reverse=True)

# Guardar las 10 mejores recomendaciones en un dataframe
df_recommendations = pd.DataFrame(columns=['user_id', 'imdb_id', 'predicted_rating'])
for iid, est in user_predictions[:10]:
    df_recommendations = df_recommendations.append({'user_id': user_id, 'imdb_id': iid, 'predicted_rating': round(est, 2)}, ignore_index=True)

# Imprimir las 10 mejores recomendaciones para el usuario con ID
print('Las 10 mejores recomendaciones para el usuario con ID', user_id)
df_recommendations
# Out:
# Las 10 mejores recomendaciones para el usuario con ID 873
# <ipython-input-7-b5a727c4373c>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_recommendations = df_recommendations.append({'user_id': user_id, 'imdb_id': iid, 'predicted_rating': round(est, 2)}, ignore_index=True)
# <ipython-input-7-b5a727c4373c>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_recommendations = df_recommendations.append({'user_id': user_id, 'imdb_id': iid, 'predicted_rating': round(est, 2)}, ignore_index=True)
# <ipython-input-7-b5a727c4373c>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_recommendations = df_recommendations.append({'user_id': user_id, 'imdb_id': iid, 'predicted_rating': round(est, 2)}, ignore_index=True)
# ...

# %%
print('Las 10 mejores recomendaciones para el usuario con ID', user_id)
df_recommendations
# Out:
# Las 10 mejores recomendaciones para el usuario con ID 873
#   user_id    imdb_id  predicted_rating
# 0     873  tt0050083              9.82
# 1     873  tt0468569              9.75
# 2     873  tt0172495              9.60
# 3     873  tt0111161              9.51
# 4     873  tt0137523              9.49
# 5     873  tt0114369              9.45
# 6     873  tt0086879              9.45
# 7     873  tt0109830              9.42
# 8     873  tt2980516              9.41
# 9     873  tt0114814              9.41

# %%
# OBTENER LOS NOMBRES

# Cargar el archivo movies.csv en un objeto de dataframe de pandas
medias = pd.read_csv('/content/drive/MyDrive/MASTER EOI/16. MODULO 16. Sistemas recomendadores de productos/Ejercicios_Entregas/material_apoyo/Copia de medias.csv')

# uUnion de tablas o merge por la columna imdb_id
tabla_completa = pd.merge(df_recommendations, medias[['imdb_id', 'imdb_title']], on='imdb_id', how='left')

tabla_completa
# Out:
#   user_id    imdb_id  predicted_rating                imdb_title
# 0     873  tt0050083              9.82              12 Angry Men
# 1     873  tt0468569              9.75           The Dark Knight
# 2     873  tt0172495              9.60                 Gladiator
# 3     873  tt0111161              9.51  The Shawshank Redemption
# 4     873  tt0137523              9.49                Fight Club
# 5     873  tt0114369              9.45                     Se7en
# 6     873  tt0086879              9.45                   Amadeus
# 7     873  tt0109830              9.42              Forrest Gump
# 8     873  tt2980516              9.41  The Theory of Everything
# 9     873  tt0114814              9.41        The Usual Suspects

# %%
# Calificacion promedio de las peliculas en el conjunto de datos
average_rating = tabla_completa['predicted_rating'].mean()
print('La calificación promedio de las películas en el conjunto de datos es:', average_rating)
# Out:
# La calificación promedio de las películas en el conjunto de datos es: 9.530999999999999

# %% [markdown]
# El modelo no es adecuado para ciertos tipos de usuarios: Cada modelo de recomendación tiene sus fortalezas y debilidades. Es posible que el modelo utilizado no sea adecuado para ciertos tipos de usuarios. Por ejemplo, un modelo de filtrado colaborativo basado en usuarios puede no funcionar bien para usuarios con gustos muy únicos o raros.
#
# No se incluyen suficientes valoraciones del usuario: Si un usuario no ha valorado suficientes películas en el conjunto de datos, entonces el modelo puede tener dificultades para hacer recomendaciones precisas para ese usuario.
# El conjunto de datos puede dividirse en conjuntos de entrenamiento y prueba para evaluar el rendimiento del modelo. Si un usuario en particular no está en el conjunto de prueba, entonces no se generarán recomendaciones para ese usuario.
#
# El código puede no estar generando recomendaciones para todos los usuarios porque algunos de ellos pueden no haber proporcionado ninguna calificación en el conjunto de datos original, por lo que no hay datos para generar recomendaciones. Esto puede explicar por qué algunos de los dataframes están vacíos.
#
# Además, el código actualmente solo está imprimiendo las mejores recomendaciones para un usuario en particular, lo que puede no ser representativo de todas las recomendaciones que el modelo puede generar para ese usuario. Si desea imprimir las mejores recomendaciones para cada usuario, debe cambiar el valor de top_n en la línea 35 a 3 (o cualquier otro número de su elección) para que se muestren las mejores 3 recomendaciones para cada usuario en lugar de solo la mejor recomendación.

# %%
# Las 10 películas con mayor numero de recomendaciones

top_recommended_movies = df_rating_filtrados['imdb_id'].value_counts().head(10)
print('Las 10 películas más recomendadas son:')
top_recommended_movies
# Out:
# Las 10 películas más recomendadas son:
# tt1454468    155
# tt0993846    135
# tt0770828    133
# tt1670345    132
# tt0816711    124
# tt0816692    123
# tt1300854    123
# tt1535109    120
# tt1663202    119
# tt1392214    117
# Name: imdb_id, dtype: int64

# %%
# OBTENER NOMBRES

top_recommended_movies = df_rating_filtrados['imdb_id'].value_counts().head(10).reset_index()
top_recommended_movies.columns = ['imdb_id', 'num_recommendations']

# %%
top10General = pd.merge(top_recommended_movies, medias[['imdb_id', 'imdb_title']], on='imdb_id', how='left')
top10General = top10General.rename(columns={'imdb_title': 'title'})
print('Las 10 películas más recomendadas son:')
print(top10General[['imdb_id','title']].iloc[:10])
# Out:
# Las 10 películas más recomendadas son:
#      imdb_id                    title
# 0  tt1454468                  Gravity
# 1  tt0993846  The Wolf of Wall Street
# 2  tt0770828             Man of Steel
# 3  tt1670345           Now You See Me
# 4  tt0816711              World War Z
# 5  tt0816692             Interstellar
# 6  tt1300854               Iron Man 3
# 7  tt1535109         Captain Phillips
# 8  tt1663202             The Revenant
# 9  tt1392214                Prisoners

# %% [markdown]
# CALCULANDO LOS ESTADISTICOS PRINCIPALES

# %%
mainStats = df_rating_filtrados['rating'].describe()
print('Los estdisticos principales para las calificaciones de películas en el conjunto de datos es: \n', mainStats)
# Out:
# Los estdisticos principales para las calificaciones de películas en el conjunto de datos es:
#  count    54323.000000
# mean         7.229277
# std          1.829680
# min          0.000000
# 25%          6.000000
# 50%          7.000000
# 75%          8.000000
# max         10.000000
# Name: rating, dtype: float64

# %% [markdown]
# Calificación promedio por usuario: Podemos calcular la calificación promedio por usuario utilizando el método groupby() en la columna user_id y luego aplicando la función mean() en la columna rating.

# %%
average_ratings_by_user = df_rating_filtrados.groupby('user_id')['rating'].mean()
print('La calificación promedio por usuario es:')
average_ratings_by_user
# Out:
# La calificación promedio por usuario es:
# user_id
# 116      7.866667
# 170      8.600000
# 254      7.558824
# 268      7.615385
# 407      8.590909
#            ...
# 71432    6.521739
# 71502    7.113383
# 71604    6.592105
# 71639    8.920000
# 71700    6.181818
# Name: rating, Length: 1000, dtype: float64

# %%
import plotly.graph_objects as go

# Obtener los valores de calificación por usuario
ratings_by_user = df_rating_filtrados.groupby('user_id')['rating'].agg(['count', 'mean'])

# Crear una figura de gráfico de dispersión
fig = go.Figure(go.Scatter(
    x=ratings_by_user['count'],
    y=ratings_by_user['mean'],
    mode='markers',
    marker=dict(
        color=ratings_by_user['mean'],
        size=10,
        colorscale='Viridis',
        showscale=True
    )
))

# Agregar títulos y etiquetas de ejes
fig.update_layout(
    title='Distribución de calificaciones por usuario',
    xaxis_title='Número de calificaciones',
    yaxis_title='Calificación promedio'
)

# Mostrar el gráfico
fig.show()

#---- Upload de grafica a plotly charStudio
py.plot(fig, filename='distCalifUser', auto_open=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Media de calificación para el usuario con id = 873
average_ratings_by_user.loc[873]
# Out:
# 8.10344827586207

# %% [markdown]
# Número total de películas por usuario: Podemos contar el número total de películas que ha visto cada usuario utilizando el método value_counts() en la columna user_id

# %%
movies_per_user = df_rating_filtrados['user_id'].value_counts()
print('El número total de películas vistas por cada usuario es:')
print(movies_per_user)
# Out:
# El número total de películas vistas por cada usuario es:
# 9662     801
# 26806    610
# 24375    550
# 71502    538
# 9087     531
#         ...
# 55470     11
# 34770     11
# 57339     11
# 2658      11
# 71700     11
# Name: user_id, Length: 1000, dtype: int64

# %%
import plotly.graph_objects as go
#df_rating_filtrados['rating']
#movies_per_user.values
# Obtener el número de películas vistas por usuario
movies_per_user = df_rating_filtrados['user_id'].value_counts()

# Crear una figura de gráfico de dispersión
fig = go.Figure(go.Scatter(
    x=movies_per_user.values,
    y=movies_per_user.index,
    mode='markers',
    marker=dict(
        color=df_rating_filtrados['rating'],
        size=10,
        colorscale='Viridis',
        showscale=True
    )
))

# Agregar títulos y etiquetas de ejes
fig.update_layout(
    title='Número total de películas vistas por usuario y rating medio',
    xaxis_title='Número de películas vistas',
    yaxis_title='ID de usuario'
)

# Mostrar el gráfico
fig.show()

#---- Upload de grafica a plotly charStudio
py.plot(fig, filename='totalPeliculasUserRating', auto_open=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Numero de peliculas vistas por el usuario con id 873
movies_per_user.loc[873]
# Out:
# 29

# %% [markdown]
# Distribución de calificaciones: Podemos visualizar la distribución de calificaciones en el conjunto de datos utilizando un histograma.

# %%
import plotly.graph_objects as go

fig = go.Figure(go.Histogram(
    x=df_rating_filtrados['rating'],
    nbinsx=10,
    marker=dict(
        color='darkblue',
    ),
    opacity=0.75
))

fig.update_layout(
    title='Distribución de calificaciones',
    xaxis_title='Calificación',
    yaxis_title='Frecuencia',
    font=dict(
        family='Arial, sans-serif',
        size=18,
        color='black'
    ),
    bargap=0.1,
    bargroupgap=0.1
)

fig.show()

#---- Upload de grafica a plotly charStudio
py.plot(fig, filename='DistribCalif', auto_open=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Tendencias de calificación por tiempo: Podemos visualizar cómo ha cambiado la calificación promedio con el tiempo utilizando un gráfico de línea.

# %%
import pandas as pd
import plotly.graph_objects as go

# Leer los datos

# Convertir la columna 'time' a datetime
df_rating_filtrados['time'] = pd.to_datetime(df_rating_filtrados['time'], unit='s')

# Extraer la hora del día de la columna 'time'
df_rating_filtrados['hour'] = df_rating_filtrados['time'].dt.hour

# Contar el número de calificaciones registradas en cada hora
ratings_by_hour = df_rating_filtrados.groupby('hour')['rating'].count()

# Crear la figura del gráfico de barras
fig = go.Figure(go.Bar(
    x=ratings_by_hour.index,
    y=ratings_by_hour.values,
    marker_color='purple'
))

# Agregar títulos y etiquetas de ejes
fig.update_layout(
    title='Número de calificaciones por hora del día',
    xaxis_title='Hora del día',
    yaxis_title='Número de calificaciones'
)

# Mostrar el gráfico
fig.show()

#---- Upload de grafica a plotly charStudio
py.plot(fig, filename='califHoraDelDia', auto_open=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_rating_filtrados['time']
# Out:
# 0       2019-08-02 08:03:06
# 1       2019-09-29 15:30:38
# 2       2019-01-16 07:17:26
# 3       2019-07-18 01:02:51
# 4       2019-08-07 04:21:48
#                 ...
# 54318   2013-08-11 19:38:09
# 54319   2013-06-14 21:07:28
# 54320   2014-02-01 20:59:57
# 54321   2013-09-11 15:49:23
# 54322   2013-07-27 22:13:18
# Name: time, Length: 54323, dtype: datetime64[ns]

# %%
# Crear columnas para el año y mes de cada registro
df_rating_filtrados['year'] = df_rating_filtrados['time'].dt.year
df_rating_filtrados['month'] = df_rating_filtrados['time'].dt.month

# Contar el número de vistas y calcular la media de rating para cada combinación de año y mes
df_aggregated = df_rating_filtrados.groupby(['year', 'month']).agg({'rating': 'mean', 'user_id': 'count'}).reset_index()
df_aggregated = df_aggregated.rename(columns={'user_id': 'num_vistas'})

# Crear un gráfico de burbujas con información por año y mes
fig = px.scatter(df_aggregated, x='year', y='month', size='num_vistas', color='rating', 
                 hover_data=['num_vistas', 'rating'], title='Cantidad de valoraciones y media de rating por mes y año',
                 color_continuous_scale=px.colors.sequential.Plasma,
                 range_color=[df_aggregated['rating'].min(), df_aggregated['rating'].max()],
                 size_max=50)
fig.update_layout(xaxis_title='Año', yaxis_title='Mes', legend_title='Media de rating')
fig.show()
#---- Upload de grafica a plotly charStudio
py.plot(fig, filename='NumValoracionesMesAnio', auto_open=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
